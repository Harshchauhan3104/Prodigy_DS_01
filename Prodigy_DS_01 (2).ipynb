# %%
import pandas as pd
import matplotlib.pyplot as plt

# Creating a dummy dataset
data = {
    'Gender': ['Male', 'Female', 'Female', 'Male', 'Female', 'Male', 'Male', 'Female', 'Male', 'Female','Male','Male','Male','Male','Female','Female', 'Female', 'Male', 'Female', 'Male', 'Male', 'Female', 'Male', 'Female','Male','Female', 'Female', 'Male', 'Female', 'Male', 'Male', 'Female', 'Male', 'Female','Male','Female', 'Female', 'Male', 'Female', 'Male', 'Male', 'Female', 'Male', 'Female','Male','Female', 'Female', 'Male', 'Female', 'Male', 'Male', 'Female', 'Male', 'Female','Male','Female', 'Female', 'Male', 'Female', 'Male', 'Male', 'Female', 'Male', 'Female','Male'],
    'Age': [23, 45, 31, 22, 34, 42, 29, 30, 27, 33,45,25,86,43,15, 22, 34, 42, 29, 30, 27, 33,45,25,86, 22, 34, 42, 29, 30, 27, 33,45,25,86, 22, 34, 42, 29, 30, 27, 33,45,25,86, 22, 34, 42, 29, 30, 27, 33,45,25,86, 22, 34, 42, 29, 30, 27, 33,45,25,86]
}
df = pd.DataFrame(data)

# Plotting the distribution of the categorical variable (Gender)
plt.figure(figsize=(10, 5))
df['Gender'].value_counts().plot(kind='bar', color=['blue', 'orange'])
plt.title('Distribution of Gender')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.xticks(rotation=0)
plt.show()

# Plotting the distribution of the continuous variable (Age)
plt.figure(figsize=(10, 5))
plt.hist(df['Age'], bins=5, color='green', edgecolor='black')
plt.title('Distribution of Age')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()
